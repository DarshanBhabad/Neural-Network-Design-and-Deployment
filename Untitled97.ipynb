# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Flatten
from tensorflow.keras.datasets import mnist
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
import numpy as np

# -------------------------------
# Load MNIST dataset
# -------------------------------
(x_train, y_train), (x_test, y_test) = mnist.load_data()

print("Training data shape:", x_train.shape)
print("Testing data shape:", x_test.shape)

# -------------------------------
# Display input images (Training samples)
# -------------------------------
plt.figure(figsize=(8, 4))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_train[i], cmap='gray')
    plt.title(f"Label: {y_train[i]}")
    plt.axis('off')
plt.suptitle("Sample MNIST Training Images", fontsize=14)
plt.tight_layout()
plt.show()

# -------------------------------
# Normalize and reshape data
# -------------------------------
x_train = x_train / 255.0
x_test = x_test / 255.0

x_train = x_train.reshape(-1, 28, 28, 1)
x_test = x_test.reshape(-1, 28, 28, 1)

# One-hot encode labels
y_train_cat = to_categorical(y_train, 10)
y_test_cat = to_categorical(y_test, 10)

# -------------------------------
# Build the MLP model
# -------------------------------
model = Sequential()
model.add(Flatten(input_shape=(28, 28, 1)))
model.add(Dense(200, activation='relu'))
model.add(Dense(150, activation='relu'))
model.add(Dense(10, activation='softmax'))

model.summary()

# -------------------------------
# Compile the model
# -------------------------------
model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

# -------------------------------
# Train the model
# -------------------------------
history = model.fit(
    x_train, y_train_cat,
    epochs=10,
    batch_size=128,
    validation_split=0.2
)

# -------------------------------
# Evaluate the model
# -------------------------------
test_loss, test_accuracy = model.evaluate(x_test, y_test_cat)
print(f"\nTest Accuracy: {test_accuracy * 100:.2f}%")

# -------------------------------
# Predictions on test images
# -------------------------------
predictions = model.predict(x_test)
predicted_labels = np.argmax(predictions, axis=1)

# -------------------------------
# Display test images with predictions
# -------------------------------
plt.figure(figsize=(10, 4))
for i in range(10):
    plt.subplot(2, 5, i + 1)
    plt.imshow(x_test[i].reshape(28, 28), cmap='gray')
    plt.title(f"True: {y_test[i]} | Pred: {predicted_labels[i]}")
    plt.axis('off')
plt.suptitle("MNIST Test Images: True vs Predicted Labels", fontsize=14)
plt.tight_layout()
plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 1s 0us/step
# Training data shape: (60000, 28, 28)
# Testing data shape: (10000, 28, 28)
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 784)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 200)            │       157,000 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 150)            │        30,150 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 10)             │         1,510 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 188,660 (736.95 KB)
#  Trainable params: 188,660 (736.95 KB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 8ms/step - accuracy: 0.8409 - loss: 0.5763 - val_accuracy: 0.9548 - val_loss: 0.1570
# Epoch 2/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9625 - loss: 0.1294 - val_accuracy: 0.9677 - val_loss: 0.1070
# Epoch 3/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9769 - loss: 0.0766 - val_accuracy: 0.9677 - val_loss: 0.1088
# Epoch 4/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9829 - loss: 0.0569 - val_accuracy: 0.9698 - val_loss: 0.0991
# Epoch 5/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9875 - loss: 0.0392 - val_accuracy: 0.9734 - val_loss: 0.0886
# Epoch 6/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9918 - loss: 0.0285 - val_accuracy: 0.9757 - val_loss: 0.0822
# Epoch 7/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 4s 10ms/step - accuracy: 0.9931 - loss: 0.0232 - val_accuracy: 0.9760 - val_loss: 0.0877
# Epoch 8/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9953 - loss: 0.0165 - val_accuracy: 0.9765 - val_loss: 0.0896
# Epoch 9/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9960 - loss: 0.0136 - val_accuracy: 0.9762 - val_loss: 0.0919
# Epoch 10/10
# 375/375 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9952 - loss: 0.0156 - val_accuracy: 0.9767 - val_loss: 0.0965
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - accuracy: 0.9740 - loss: 0.0880
#
# Test Accuracy: 97.82%
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step
